# %% [markdown]
# Reading Single English Passage from PDF

# %%
import os
import pymupdf

# %%
file_path = os.path.join("..","data","three_little_pigs.pdf")
print(file_path)
# Out:
# ../data/three_little_pigs.pdf

# %%
doc = pymupdf.open(file_path)

english_lines = []

for page in doc:
    data = page.get_text("dict")

    for block in data["blocks"]:
        if "lines" not in block:
            continue

        block_text = []

        for line in block["lines"]:
            line_text = "".join(span["text"] for span in line["spans"]).strip()
            if line_text:
                block_text.append(line_text)

        if block_text:
            english_lines.append(" ".join(block_text))

print("\n\n".join(english_lines))
# Out:
# Three Little Pigs
#
# Once upon a time, three little pigs said goodbye to their mother and went out into the world to build their own lives. The first little pig, who loved to play more than work, quickly threw together a house made entirely of loose straw and went off to spend his afternoon singing. The second little pig wanted to relax too, so he gathered fallen branches and quickly constructed a simple house of sticks. However, the third little pig was wise and patient; knowing that danger could lurk in the woods, he put in long hours of hard labor to build a sturdy, reliable house made of heavy clay bricks and mortar.
#
# Before long, a hungry Big Bad Wolf came creeping through the forest and spotted the flimsy house of straw. He knocked loudly on the door and cried, "Little pig, little pig, let me come in!" to which the frightened pig replied, "No, no, by the hair on my chinny-chin-chin!" The wolf grinned, warning, "Then I'll huff, and I'll puff, and I'll blow your house in!" With a mighty breath, the wolf blew the straw house completely away, forcing the terrified little pig to sprint as fast as his legs could carry him straight to his brother’s house of sticks.
#
# The wolf followed the scent to the second house and knocked again, demanding entry from the two brothers. When they defiantly refused, the wolf inhaled deeply and let out a furious blast of air that shattered the house of sticks into splinters. Panicked and squealing, the two pigs scrambled through the undergrowth and burst into the third brother's brick home, slamming the heavy wooden door just in time. The wolf arrived and huffed, and he puffed, and he blew until he was completely blue in the face, but the solid brick walls didn't even shake. Realizing he couldn't blow the house down, the furious wolf climbed onto the roof to slide down the chimney, but the clever third pig was ready. He lit a roaring fire and placed a giant pot of boiling water in the hearth, so when the wolf slid down, he crashed straight into the scalding pot. With a painful yelp, the wolf shot back up the chimney and fled deep into the forest, leaving the three little pigs to live safely and happily together in the sturdy brick house forever after.

# %%
print((english_lines[1]))
# Out:
# Once upon a time, three little pigs said goodbye to their mother and went out into the world to build their own lives. The first little pig, who loved to play more than work, quickly threw together a house made entirely of loose straw and went off to spend his afternoon singing. The second little pig wanted to relax too, so he gathered fallen branches and quickly constructed a simple house of sticks. However, the third little pig was wise and patient; knowing that danger could lurk in the woods, he put in long hours of hard labor to build a sturdy, reliable house made of heavy clay bricks and mortar.

# %%
def split_title_body(lines):
    title = lines[0] if lines else ""
    body = "\n".join(lines[1:]) if len(lines) > 1 else ""
    return title, body


title, body = split_title_body(english_lines)

english_object = {
    "title": title,
    "englishVersion": body
}

print(english_object)
# Out:
# {'title': 'Three Little Pigs', 'englishVersion': 'Once upon a time, three little pigs said goodbye to their mother and went out into the world to build their own lives. The first little pig, who loved to play more than work, quickly threw together a house made entirely of loose straw and went off to spend his afternoon singing. The second little pig wanted to relax too, so he gathered fallen branches and quickly constructed a simple house of sticks. However, the third little pig was wise and patient; knowing that danger could lurk in the woods, he put in long hours of hard labor to build a sturdy, reliable house made of heavy clay bricks and mortar.\nBefore long, a hungry Big Bad Wolf came creeping through the forest and spotted the flimsy house of straw. He knocked loudly on the door and cried, "Little pig, little pig, let me come in!" to which the frightened pig replied, "No, no, by the hair on my chinny-chin-chin!" The wolf grinned, warning, "Then I\'ll huff, and I\'ll puff, and I\'ll blow your house in!" With a mighty breath, the wolf blew the straw house completely away, forcing the terrified little pig to sprint as fast as his legs could carry him straight to his brother’s house of sticks.\nThe wolf followed the scent to the second house and knocked again, demanding entry from the two brothers. When they defiantly refused, the wolf inhaled deeply and let out a furious blast of air that shattered the house of sticks into splinters. Panicked and squealing, the two pigs scrambled through the undergrowth and burst into the third brother\'s brick home, slamming the heavy wooden door just in time. The wolf arrived and huffed, and he puffed, and he blew until he was completely blue in the face, but the solid brick walls didn\'t even shake. Realizing he couldn\'t blow the house down, the furious wolf climbed onto the roof to slide down the chimney, but the clever third pig was ready. He lit a roaring fire and placed a giant pot of boiling water in the hearth, so when the wolf slid down, he crashed straight into the scalding pot. With a painful yelp, the wolf shot back up the chimney and fled deep into the forest, leaving the three little pigs to live safely and happily together in the sturdy brick house forever after.'}

# %%
from services.fable_extraction_pipeline.tokenize_english_version_story import TokenizeEnglishVersion
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from services.fable_extraction_pipeline.tokenize_english_version_story import TokenizeEnglishVersion
#
# ModuleNotFoundError: No module named 'services.fable_extraction_pipeline.tokenize_english_version_story'

# %%
req = TokenizeEnglishVersion(english_object)
res = req.tokenize_english_version()
print(res)

# %% [markdown]
# Reading Multiple English Passages from PDF

# %%
import os
import pymupdf
file_path = os.path.join("..","data","multi_para.pdf")
print(file_path)
# Out:
# ../data/multi_para.pdf

# %%
doc = pymupdf.open(file_path)

for page in doc:
    text = page.get_text()

    for line in text.splitlines():
        if line.strip() and line.strip().isupper():
            print(line)
# Out:
# THE TORTOISE AND THE HARE
# THE BOY WHO CRIED WOLF
# THE LION AND THE MOUSE
# THE ANT AND THE GRASSHOPPER
# THE FOX AND THE GRAPES
# THE GOOSE THAT LAID THE GOLDEN EGGS
# THE NORTH WIND AND THE SUN

# %%
import pymupdf

passage_array = []
current_title = None
current_text = []

doc = pymupdf.open(file_path)

for page in doc:
    text = page.get_text()

    for line in text.splitlines():
        line = line.strip()

        if not line:
            continue

        # Detect title
        if line.isupper():
            # Save previous passage
            if current_title:
                passage_array.append({
                    "title": current_title,
                    "englishVersion": " ".join(current_text).strip()
                })

            current_title = line
            current_text = []

        else:
            current_text.append(line)

# Save last passage
if current_title:
    passage_array.append({
        "title": current_title,
        "englishVersion": " ".join(current_text).strip()
    })

print(passage_array)
# Out:
# [{'title': 'THE TORTOISE AND THE HARE', 'englishVersion': 'Once upon a time, a speedy hare loved to boast about how fast he could run. Tired of hearing him brag, a humble tortoise challenged him to a race. The hare laughed at the idea but agreed. When the race began, the hare quickly ran far ahead and, feeling confident, decided to take a nap under a tree. Meanwhile, the tortoise kept moving slowly and steadily without stopping. By the time the hare woke up, the tortoise was nearing the finish line. The hare sprinted as fast as he could, but it was too late. The tortoise crossed the finish line first and won the race. From that day on, everyone remembered that slow and steady wins the race.'}, {'title': 'THE BOY WHO CRIED WOLF', 'englishVersion': 'Once upon a time, a young shepherd boy watched over a flock of sheep near a village. Bored and wanting attention, he shouted, “Wolf! Wolf! A wolf is attacking the sheep!” The villagers rushed to help, only to find that there was no wolf. The boy laughed at their surprise. A few days later, he played the same trick again, and the villagers were annoyed when they discovered it was another false alarm. Then one evening, a real wolf appeared and began chasing the sheep. The frightened boy cried out for help, but the villagers thought he was joking once more and ignored him. The wolf scattered the flock, and the boy learned an important lesson: people stop believing those who tell lies, even when they are telling the truth.'}, {'title': 'THE LION AND THE MOUSE', 'englishVersion': "Once upon a time, a mighty lion was sleeping peacefully in the forest. A tiny mouse accidentally ran across his paw and woke him up. Angry, the lion caught the mouse and was about to eat him. The frightened mouse begged for mercy and promised to help the lion someday. The lion laughed at the idea but let him go. A few days later, the lion became trapped in a hunter's net. Hearing his roars, the mouse rushed over and began gnawing through the ropes. Soon, the lion was free. The lion thanked the mouse and learned that even the smallest friend can be a great help."}, {'title': 'THE ANT AND THE GRASSHOPPER', 'englishVersion': 'Once upon a time, an ant spent the summer gathering food and storing it for winter. Nearby, a grasshopper sang songs and played all day long. He laughed at the ant for working so hard. When winter arrived, the ground was covered with snow, and food became scarce. The ant stayed warm and had plenty to eat. The grasshopper, however, was hungry and cold. Realizing his mistake, he wished he had prepared for the future.'}, {'title': 'THE FOX AND THE GRAPES', 'englishVersion': 'Once upon a time, a hungry fox was walking through a vineyard. He noticed a bunch of ripe grapes hanging high above him. The fox jumped again and again, trying to reach them, but they were too high. After many failed attempts, he finally gave up and walked away. As he left, he said, “Those grapes were probably sour anyway.” The fox pretended he did not want them because he could not have them.'}, {'title': 'THE GOOSE THAT LAID THE GOLDEN EGGS', 'englishVersion': 'Once upon a time, a farmer owned a goose that laid a golden egg every day. The farmer sold the eggs and soon became wealthy. However, he grew greedy and wanted all the gold at once. Thinking the goose must contain a treasure inside, he killed it and cut it open. To his disappointment, the goose was just like any other goose. The farmer lost the goose and the golden eggs forever.'}, {'title': 'THE NORTH WIND AND THE SUN', 'englishVersion': 'Once upon a time, the North Wind and the Sun argued about who was stronger. They decided to test their strength on a traveler walking along a road. The North Wind blew as hard as he could, but the traveler only wrapped his coat more tightly around himself. Then the Sun shone warmly. The traveler soon felt hot and took off his coat. The Sun smiled and showed that gentleness can succeed where force fails.'}]
