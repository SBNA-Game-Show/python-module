# %%
from repository.gurukula_metadata_repo import RetrieveUnusedStories

# %%
req = RetrieveUnusedStories()
res = req.get_all()
print(res)
# Out:
# ATLAS_URI = mongodb+srv://codingbhojgc_db_user:yWtbFMMMfjilWHNd@myproject.qevsog5.mongodb.net/sb-dict?appName=MyProject
# ...

# %%
from repository.gurukula_metadata_repo import RetrieveStoryById

# %%
story_req = RetrieveStoryById("e2780f95-4807-4504-84cc-fd2310906a04")
story = story_req.get()
print(story)
# Out:
# ATLAS_URI = mongodb+srv://codingbhojgc_db_user:yWtbFMMMfjilWHNd@myproject.qevsog5.mongodb.net/sb-dict?appName=MyProject
# {'_id': 'e2780f95-4807-4504-84cc-fd2310906a04', 'story_url': '/sa/saralakathah/chaturah-kaakah-2', 'title': 'चतुरः काकः', 'used': False, 'usedDate': None}

# %%
from repository.gurukula_metadata_repo import UpdateStoryStatus

# %%
updater = UpdateStoryStatus("e2780f95-4807-4504-84cc-fd2310906a04")
update_result = updater.update()
print(update_result)
# Out:
# ATLAS_URI = mongodb+srv://codingbhojgc_db_user:yWtbFMMMfjilWHNd@myproject.qevsog5.mongodb.net/sb-dict?appName=MyProject
# {'success': True, 'modified_count': 1}
