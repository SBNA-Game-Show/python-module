# %%
from repository.gurukula_metadata_repo import RetrieveUnusedStories

# %%
req = RetrieveUnusedStories()
res = req.get_all()
print(res)
# Out:
# ATLAS_URI = mongodb+srv://codingbhojgc_db_user:yWtbFMMMfjilWHNd@myproject.qevsog5.mongodb.net/sb-dict?appName=MyProject
# [{'category': 'सरलकथाः', 'category_link': '/sa/saralakathah', 'story': {'_id': '24ef313d-0d0f-44d2-bf4d-6feafec89e2b', 'story_url': '/sa/saralakathah/chaturah-kaakah-2', 'title': 'चतुरः काकः', 'used': False, 'usedDate': None}}, {'category': 'सरलकथाः', 'category_link': '/sa/saralakathah', 'story': {'_id': 'b43702d7-300b-46ae-9ed8-053ceaf359b9', 'story_url': '/sa/saralakathah/dadaatu-grhnaatu-3', 'title': 'ददातु-गृह्णातु', 'used': False, 'usedDate': None}}, {'category': 'सरलकथाः', 'category_link': '/sa/saralakathah', 'story': {'_id': '73a80267-01a8-4f69-b350-0f48663ac4cf', 'story_url': '/sa/saralakathah/parayatnasya-vaishishtyam-4', 'title': 'प्रयत्नस्य\xa0वैशिष्ट्यम्', 'used': False, 'usedDate': None}}, {'category': 'सरलकथाः', 'category_link': '/sa/saralakathah', 'story': {'_id': '121d3a31-f911-44a1-8c86-61c3880241e1', 'story_url': '/sa/saralakathah/shrgaalasya-kathaa-5', 'title': 'शृगालस्य कथा', 'used': False, 'usedDate': None}}, {'category': 'सरलकथाः', 'category_link': '/sa/saralakathah', 'story': {'_id': '986f97f8-f83f-4349-991e-8254cee96b08', 'story_url': '/sa/saralakathah/satyapriyah-kaashthikah-6', 'title': 'सत्यप्रियः काष्ठिकः', 'used': False, 'usedDate': None}}, {'category': 'सरलकथाः', 'category_link': '/sa/saralakathah', 'story': {'_id': '07643158-d040-4d55-af46-240b4b302741', 'story_url': '/sa/saralakathah/mandukadwayam-7', 'title': 'मण्डूकद्वयम्', 'used': False, 'usedDate': None}}, {'category': 'सरलकथाः', 'category_link': '/sa/saralakathah', 'story': {'_id': '9e0d90f2-cc3d-436f-ae20-00a03b263f8c', 'story_url': '/sa/saralakathah/sudheerasya-kathaa-8', 'title': 'सुधीरस्य कथा', 'used': False, 'usedDate': None}}, {'category': 'सरलकथाः', 'category_link': '/sa/saralakathah', 'story': {'_id': '67a24110-65df-4ee5-8398-081edc49c6d9', 'story_url': '/sa/saralakathah/nashtah-pishta-ghatah-9', 'title': 'नष्टः पिष्टघटः', 'used': False, 'usedDate': None}}, {'category': 'सरलकथाः', 'category_link': '/sa/saralakathah', 'story': {'_id': '5221b8ee-b0c8-4fb2-b592-baf69d79305d', 'story_url': '/sa/saralakathah/aikyameva-balam-10', 'title': 'ऐक्यमेव बलम्', 'used': False, 'usedDate': None}}, {'category': 'सरलकथाः', 'category_link': '/sa/saralakathah', 'story': {'_id': '043a2182-b136-4a22-84c3-3eac817a8301', 'story_url': '/sa/saralakathah/bakasya-vetanam-11', 'title': 'बकस्य वेतनम्', 'used': False, 'usedDate': None}}, {'category': 'सरलकथाः', 'category_link': '/sa/saralakathah', 'story': {'_id': '83b680a4-df7c-41df-892f-68b1d3a641e5', 'story_url': '/sa/saralakathah/chaturah-vruddhah-12', 'title': 'चतुरः वृद्धः', 'used': False, 'usedDate': None}}, {'category': 'सरलकथाः', 'category_link': '/sa/saralakathah', 'story': {'_id': 'eeeace43-0c60-4700-a2d8-033b83e940a7', 'story_url': '/sa/saralakathah/murkhah-kakah-13', 'title': 'मूर्खः काकः', 'used': False, 'usedDate': None}}, {'category': 'सरलकथाः', 'category_link': '/sa/saralakathah', 'story': {'_id': '450a865c-2ce2-4f86-bd57-02293cd6e227', 'story_url': '/sa/saralakathah/vyagrah-vyagrah-14', 'title': 'व्याघ्रः\xa0व्याघ्रः', 'used': False, 'usedDate': None}}, {'category': 'सरलकथाः', 'category_link': '/sa/saralakathah', 'story': {'_id': '20ce3606-df30-4a36-9e82-172e69850fc5', 'story_url': '/sa/saralakathah/shoki-kakah-15', 'title': 'शोकी काकः', 'used': False, 'usedDate': None}}, {'category': 'सरलकथाः', 'category_link': '/sa/saralakathah', 'story': {'_id': '25db1183-35a4-4157-a46d-24729275a78b', 'story_url': '/sa/saralakathah/lokakalyanakaryam-laghutvaya-na-16', 'title': 'लोककल्याणकार्यं लघुत्वाय न', 'used': False, 'usedDate': None}}, {'category': 'सरलकथाः', 'category_link': '/sa/saralakathah', 'story': {'_id': 'd415550e-998a-442a-804a-fbb67517c38d', 'story_url': '/sa/saralakathah/sinhamushakayoh-maitreeh-17', 'title': 'सिंहमूषकयोः मैत्री', 'used': False, 'usedDate': None}}, {'category': 'सरलकथाः', 'category_link': '/sa/saralakathah', 'story': {'_id': '291b2f60-a00d-4bcf-b14b-6c2b757c2337', 'story_url': '/sa/saralakathah/doordrshtyaah-mahatvam-18', 'title': 'दूरदृष्ट्याः महत्वम्', 'used': False, 'usedD ...

# %%
from repository.gurukula_metadata_repo import RetrieveStoryById

# %%
story_req = RetrieveStoryById("b4be16ba-22a5-4ad8-8e3e-52d5c21d73e8")
story = story_req.get()
print(story)
# Out:
# ATLAS_URI = mongodb+srv://codingbhojgc_db_user:yWtbFMMMfjilWHNd@myproject.qevsog5.mongodb.net/sb-dict?appName=MyProject
# None
