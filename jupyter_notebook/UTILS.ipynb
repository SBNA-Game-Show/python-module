# %%
from services.tokenize_sanskrit_passage_web import TokenizeSanskritPassageWeb
from utils.file_system_reader import FileSystemReader
from utils.file_system_writer import WriteToFileSystem

# %%
reader = FileSystemReader("stories_raw.json")
raw_data = reader.read_file()
print(raw_data)
# Out:
# {'title': {'english_version': 'rabbit, weasel, cat', 'sanskrit_version': 'शशकः नकुलः मार्जारी च'}, 'actors': ['rabbit', 'weasel', 'cat'], 'storyMoral': 'The strong can settle questions to their own advantage', 'englishVersion': 'When the rabbit left his home, a weasel moved in and refused to move out again. A great dispute arose over this.  When the cat heard this, she offered to pacify the dispute. She asked the opponents to come closer to her, because she could not hear well. When this happened, she grabbed one of the disputants with each paw to devour them. Thus she pacified the quarrel.', 'transliteratedVersion': ['zazakaH nakulaH mArjArI ca', 'ekadine gRhAt prasthitaH ekaH zazakaH svAduM tRNaM khAditum agacchat ।', 'parantu gRhasya pidhAnaM kartuM saH vismRtavAn ।', 'yadA zazakaH gRhe na AsIt tadA ekaH nakulaH tatra Agatya zazakasya gRhaM praviSTavAn ।', 'tasmai zazakasya gRham arocata ataH tatraiva nivasituM nizcayaM kRtavAn ।', 'zazakaH Agatya nakulaM dRSTvA ca avadat –', '" m
# ...

# %%
sa_tokenizer = TokenizeSanskritPassageWeb(raw_data)
sa_tokenized_data = sa_tokenizer.tokenize()
print(sa_tokenized_data)
# Out:
# **The hare, the mongoose, and the cat.**
# *शशकः नकुलः मार्जारी च*
#
# * **शशकः**, śaśaka, śaśakaḥ, masculine noun, nominative singular, _the hare (subject)_
# * **नकुलः**, nakula, nakulaḥ, masculine noun, nominative singular, _the mongoose (subject)_
# * **मार्जारी**, mārjārī, mārjārī, feminine noun, nominative singular, _the cat (subject)_
# * **च**, ca, ca, conjunction, indeclinable, _and_
#
# **One day, a hare set out from home to eat tasty grass.**
# *एकदिने गृहात् प्रस्थितः एकः शशकः स्वादुं तृणं खादितुम् अगच्छत् ।*
#
# * **एकदिने**, ekadina, ekadine, neuter noun, locative singular, _on one day_
# * **गृहात्**, gṛha, gṛhāt, neuter noun, ablative singular, _from the house_
# * **प्रस्थितः**, prasthita, prasthitaḥ, past passive participle, nominative singular masculine, _having set out_
# * **एकः**, eka, ekaḥ, numeral/adjective, nominative singular masculine, _one_
# * **शशकः**, śaśaka, śaśakaḥ, masculine noun, nominative singular, _hare_
# ...

# %%
writer = WriteToFileSystem("sa_tok_story3.json",sa_tokenized_data)
