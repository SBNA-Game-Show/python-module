# %%
from utils.sanskrit_parser import SanskritToTransliterate,TransliterateToSanskrit

# %%
transliterator = SanskritToTransliterate("शशकः नकुलः मार्जारी च")
sentence = transliterator.transliterate()
print(sentence)
# Out:
# śaśakaḥ nakulaḥ mārjārī ca

# %%
translator = TransliterateToSanskrit(sentence)
trans_sent = translator.translate()
print(trans_sent)
# Out:
# शशकः नकुलः मार्जारी च
