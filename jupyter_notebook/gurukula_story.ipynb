# %%
import requests
import urllib3
import re
from bs4 import BeautifulSoup
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %%
base_url = "https://gurukula.com/sa/saralakathah/dadaatu-grhnaatu-3"

# %%
base_response = requests.get(base_url,timeout=10)
raw_html = base_response.text
print(raw_html)
# Out:
# <!DOCTYPE html><html><head><script>!function(f,b,e,v,n,t,s)
# {if(f.fbq)return;n=f.fbq=function(){n.callMethod?n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,document,'script','https://connect.facebook.net/en_US/fbevents.js');fbq('init','2195783624203625');</script><script src="/rcb9m59p/init.js"></script><meta charSet="utf-8"/><meta name="viewport" content="width=device-width"/><meta http-equiv="Cache-Control" content="max-age=28800"/><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-Q48HNQVBP2"></script><script id="google-analytics" strategy="afterInteractive">
#             window.dataLayer = window.dataLayer || [];
#             function gtag(){dataLayer.push(arguments);}
#             gtag(&#x27;js&#x27;, new Date());
#             gtag(&#x27;config&#x27;, &#x27;G-Q48HNQVBP2&#x27;);
#           </script><title>3.ददातु-गृह्णातु | सरलकथाः | Gurukula.com</title><meta property="og:title" content="3.ददातु-गृह्णातु | सरलकथाः | Gurukula.com | Indian culture online | Comics Audio Stories Videos"/><link rel="icon" href="/favicon.png"/><meta name="description" content="कृपणं मा याचतु - केवलं यच्छतु ।"/><meta property="og:description" content="कृपणं मा याचतु - केवलं यच्छतु ।"/><meta property="og:image" content="https://firebasestorage.googleapis.com/v0/b/gurukula-prod/o/saralakathah%2Ficons%2Fchapter0003.jpg?alt=media&amp;token=5815d50a-2ea7-4ecc-89bd-77448c0ef28a"/><meta name="keywords" content="ददातु-गृह्णातु"/><meta name="next-head-count" content="12"/><link rel="preload" href="/_next/static/css/df8332c91f5bf95f.css" as="style"/><link rel="stylesheet" href="/_next/static/css/df8332c91f5bf95f.css" data-n-g=""/><link rel="preload" href="/_next/static/css/22b45540e702db8d.css" as="style"/><link rel="stylesheet" href="/_next/static/css/22b45540e702db8d.css" data-n-p=""/><noscript data-n-css=""></noscript><script defer="" nomodule="" src="/_next/static/chunks/polyfills-c67a75d1b6f99dc8.js"></script><script src="/_next/static/chunks/webpack-dcf4136cb4ed4a3e.js" defer=""></script><script src="/_next/static/chunks/framework-5429a50ba5373c56.js" defer=""></script><script src="/_next/static/chunks/main-af4805e10c1b8e0c.js" defer=""></script><script src="/_next/static/chunks/pages/_app-3923fddd1f34cfef.js" defer=""></script><script src="/_next/static/chunks/664-5089833ba7c760b8.js" defer=""></script><script src="/_next/static/chunks/677-ba154e0d19fc2ae8.js" defer=""></script><script src="/_next/static/chunks/93-ba54b398a95b41ff.js" defer=""></script><script src="/_next/static/chunks/311-acdde8e4edecf5d2.js" defer=""></script><script src="/_next/static/chunks/184-f92a52bf60192694.js" defer=""></script><script src="/_next/static/chunks/274-76e4b878db6b2ab6.js" defer=""></script><script src="/_next/static/chunks/pages/%5B...slug%5D-22aa0ecebfbebf90.js" defer=""></script><script src="/_next/static/8WyYCQHdynV0N9dWf047J/_buildManifest.js" defer=""></script><script src="/_next/static/8WyYCQHdynV0N9dWf047J/_ssgManifest.js" defer=""></script></head><body><div id="__next"><section id="details"><header><div class="orange-topbar"><div class="text-download">Download the Gurukula App now!</div><a href="https://itunes.apple.com/us/app/gurukula-indian-culture-online/id1435154713" target="_blank" rel="noopener noreferrer" class="istore-btn"><img alt="btn-app-store" loading="eager" width="96" height="31" decoding="async" data-nimg="1" style="color:transparent" src="/_next/static/media/btn-istore.371f593b.svg"/></a><a href=" https://play.google.com/store/apps/details?id=gurukula.com.indiancultureonline" target="_blank" rel="noopener noreferrer"><img alt="btn-google-play-store" loading="eager" width="94" height="31" decoding="async" data-nimg="1" style="color:transparent" src="/_next/static/media/btn-google-store.dbaa92a1.svg"/></a></div></header><nav><div class="header header-with-topbar"><div class="container"><div class="list"><div class="toggle-and-logo"><div id="toggle-menu"><img alt="icon-toggle-menu" loading="eager" width="23" height="18" decoding="async" data-nimg="1" style="color:transparent" src="/_next/static/media/icon-toggle-menu.b288f53e.svg"/></div><div class="logo"><a href="/en"><img alt="logo" loading="eager" width="49" height="49" decoding="async" data-nimg="1" style="color:transparent" src="/_next/static/media/logo-gurukula.3431c170.png"/></a></div></div><div class="header-list"><div class="menu"><div class="close-menu"><img alt="icon-close" loading="eager" width="20" height="20" decoding="async" data-nimg="1" style="color:transparent" src="/_next/static/media/icon-close-menu.865a8005.svg"/></div><ul class="menu-list"><li><a href="/en">Home</a></li><li><a href="/courses">Courses</a></li><li><a href="/workshop">Workshops</a></li><li><a href="/donate">Donate now</a></li><div class="CustomDropdown_dropdown__jKhGg"><button class= ...

# %% [markdown]
# Parse HTML

# %%
print(type(raw_html))
# Out:
# <class 'str'>

# %%
from bs4 import BeautifulSoup
import json

soup = BeautifulSoup(raw_html, "html.parser")

next_script = soup.find("script", id="__NEXT_DATA__")

if next_script:
    raw_json = next_script.string
    next_data = json.loads(raw_json)

    print(type(next_data))
else:
    print("No __NEXT_DATA__ found")
# Out:
# <class 'dict'>

# %%
page_data = next_data["props"]["pageProps"]["data"]

print(page_data.keys())
# Out:
# dict_keys(['chapterDetailObj', 'epicChapterTitleList', 'currChapterIndexInArray', 'storyBufferData'])

# %%
# buffer_data = page_data["storyBufferData"]["Story"]["data"]

# story_html = bytes(buffer_data).decode("utf-8")

# print(story_html)
buffer_data = page_data["storyBufferData"]["Story"]["data"]

raw_bytes = bytes(buffer_data)

for encoding in ["utf-8", "cp1252", "latin-1"]:
    try:
        story_html = raw_bytes.decode(encoding)
        print("Success:", encoding)
        break
    except UnicodeDecodeError:
        print("Failed:", encoding)
# Out:
# Failed: utf-8
# Success: cp1252

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(story_html, "html.parser")

paragraphs = soup.find_all("p")

sanskrit_text = []

for p in paragraphs:
    text = p.get_text(" ", strip=True)

    if text:
        sanskrit_text.append(text)

story = "\n".join(sanskrit_text)

print(story)
# Out:
# If there are any
# errors in the script or the narration, please send a note to contactgurukula@gmail.com
# कश्चन ग्रामः
# । ग्रामे एकः कृपणः
# वसति । सः कस्मै
# अपि कदापि किमपि
# न ददाति । एकदा
# सः कृपणः अन्यं
# ग्रामं गच्छति
# । मार्गे नदी अस्ति
# । तत्र नौका अस्ति
# । नाविकः अपि अस्ति
# । कृपणः नौकायाम्
# उपविशति । नौकया
# नाविकेन सह कृपणः
# गच्छति ।
# kaścana
# grāmaḥ । grāme ekaḥ kṛpaṇaḥ
# vasati । saḥ kasmai api kadāpi kimapi na dadāti ।
# ekadā saḥ kṛpaṇaḥ anyaṃ grāmaṃ
# gacchati । mārge nadī asti । tatra naukā asti ।
# nāvikaḥ api asti । kṛpaṇaḥ
# naukāyām upaviśati । naukayā nāvikena saha kṛpaṇaḥ
# gacchati ।
# यदा नौका
# किञ्चित् दूरं
# गच्छति तदा निसर्गकोपः
# भवति । वायुः वेगेन
# वहति । नौका आन्दोलयति
# । कृपणः भीतः भवति
# । नद्यां पतति
# । किन्तु सः तरणं
# तु न जानाति ।
# yadā
# naukā kiñcit dūraṃ gacchati tadā nisargakopaḥ
# bhavati । vāyuḥ vegena vahati । naukā
# āndolayati । kṛpaṇaḥ bhītaḥ bhavati ।
# nadyāṃ patati । kintu saḥ taraṇaṃ tu na
# jānāti । सः उच्चैः
# वदति, “रक्षतु, रक्षतु”
# इति ।
# saḥ
# uccaiḥ vadati, "rakṣatu, rakṣatu" iti । नाविकः वदति
# “भोः हस्तं शीघ्रं
# ददातु” इति ।
# nāvikaḥ
# vadati "bhoḥ hastaṃ śīghraṃ dadātu"
# iti ।
# परन्तु
# एषः तु महाकृपणः
# । कदापि किमपि
# न ददाति । स्वस्य
# हस्तम् अपि न ददाति
# ।
# parantu
# eṣaḥ tu mahākṛpaṇaḥ । kadāpi
# kimapi na dadāti । svasya hastam api na dadāti ।
# नाविकः
# चिन्तयति, ‘एषः
# मूर्खः’ इति । सः
# एकम् उपायं करोति
# । वदति, “भोः मम हस्तं
# स्वीकरोतु” इति
# ।
# nāvikaḥ
# cintayati, ‘eṣaḥ mūrkhaḥ' iti । saḥ ekam
# upāyaṃ karoti । vadati, "bhoḥ mama hastaṃ
# svīkarotu" iti । कृपणः झटिति
# हस्तद्वयेन नाविकस्य
# हस्तं गृह्णाति
# । नौकायाः अन्तः
# आगच्छति ।
# kṛpaṇaḥ
# jhaṭiti hastadvayena nāvikasya hastaṃ gṛhṇāti
# । naukāyāḥ antaḥ āgacchati ।

# %%
import re

devanagari_block = re.compile(r'[\u0900-\u097F\u200C\u200D\s।,?"“”]+')

paragraphs = []

for p in soup.find_all("p"):
    text = p.get_text(" ", strip=True)

    if text.startswith("Translated by"):
        continue

    # Extract only Devanagari characters
    matches = devanagari_block.findall(text)

    sanskrit_text = " ".join(matches).strip()

    # remove empty results
    if sanskrit_text:
        paragraphs.append(sanskrit_text)


story = "\n\n".join(paragraphs)

print(story)
# Out:
# ,
#
# कश्चन ग्रामः
# । ग्रामे एकः कृपणः
# वसति । सः कस्मै
# अपि कदापि किमपि
# न ददाति । एकदा
# सः कृपणः अन्यं
# ग्रामं गच्छति
# । मार्गे नदी अस्ति
# । तत्र नौका अस्ति
# । नाविकः अपि अस्ति
# । कृपणः नौकायाम्
# उपविशति । नौकया
# नाविकेन सह कृपणः
# गच्छति ।
#
# ।
#   ।               ।
#
#   ।       ।       ।
#       ।
#     ।
#   ।
#
# यदा नौका
# किञ्चित् दूरं
# गच्छति तदा निसर्गकोपः
# भवति । वायुः वेगेन
# वहति । नौका आन्दोलयति
# । कृपणः भीतः भवति
# । नद्यां पतति
# । किन्तु सः तरणं
# तु न जानाति ।
#
# ।       ।
#   ।       ।
#     ।
#   । सः उच्चैः
# वदति, “रक्षतु, रक्षतु”
# इति ।
#
# , " ,  "   । नाविकः वदति
# “भोः हस्तं शीघ्रं
# ददातु” इति ।
#
# "       "
#   ।
#
# परन्तु
# एषः तु महाकृपणः
# । कदापि किमपि
# न ददाति । स्वस्य
# हस्तम् अपि न ददाति
# ।
#
# ।
#       ।           ।
#
# नाविकः
# चिन्तयति,  एषः
# मूर्खः  इति । सः
# एकम् उपायं करोति
# । वदति, “भोः मम हस्तं
# स्वीकरोतु” इति
# ।
#
# ,       ।
#     ।  , "
#  "   । कृपणः झटिति
# हस्तद्वयेन नाविकस्य
# हस्तं गृह्णाति
# । नौकायाः अन्तः
# आगच्छति ।
#
# ।       ।

# %%
sanskrit_passage =[]
import re

# Normalize whitespace
story = re.sub(r'\s+', ' ', story).strip()

# Split into Sanskrit sentences
sentences = [
    s.strip() + "।"
    for s in story.split("।")
    if s.strip()
]

for i, sentence in enumerate(sentences, 1):
    sanskrit_passage.append(sentence)

print(sanskrit_passage)
# Out:
# [', कश्चन ग्रामः।', 'ग्रामे एकः कृपणः वसति।', 'सः कस्मै अपि कदापि किमपि न ददाति।', 'एकदा सः कृपणः अन्यं ग्रामं गच्छति।', 'मार्गे नदी अस्ति।', 'तत्र नौका अस्ति।', 'नाविकः अपि अस्ति।', 'कृपणः नौकायाम् उपविशति।', 'नौकया नाविकेन सह कृपणः गच्छति।', 'यदा नौका किञ्चित् दूरं गच्छति तदा निसर्गकोपः भवति।', 'वायुः वेगेन वहति।', 'नौका आन्दोलयति।', 'कृपणः भीतः भवति।', 'नद्यां पतति।', 'किन्तु सः तरणं तु न जानाति।', 'सः उच्चैः वदति, “रक्षतु, रक्षतु” इति।', ', " , "।', 'नाविकः वदति “भोः हस्तं शीघ्रं ददातु” इति।', '" "।', 'परन्तु एषः तु महाकृपणः।', 'कदापि किमपि न ददाति।', 'स्वस्य हस्तम् अपि न ददाति।', 'नाविकः चिन्तयति, एषः मूर्खः इति।', 'सः एकम् उपायं करोति।', 'वदति, “भोः मम हस्तं स्वीकरोतु” इति।', ',।', ', " "।', 'कृपणः झटिति हस्तद्वयेन नाविकस्य हस्तं गृह्णाति।', 'नौकायाः अन्तः आगच्छति।']

# %% [markdown]
# convert to english

# %%
import uuid
trans_base_url = "https://dharmamitra.org/bff/api/translation"

# %%
import uuid

def _create_payload(sentences):

    return {
        "do_grammar": False,
        "input_encoding": "auto",
        "input_sentence": ", ".join(f"'{s}'" for s in sentences),
        "messages": [
            {
                "parts": [
                    {
                        "type": "text",
                        "text": ", ".join(f"'{s}'" for s in sentences)
                    }
                ],
                "id": str(uuid.uuid4()),
                "role": "user"
            }
        ],
        "mode": "normal",
        "target_lang": "english"
    }

# %%
    def _create_headers():
        return{
                "Accept": "text/event-stream",
                "Content-Type": "application/json",
                "Origin": "https://dharmamitra.org",
                "Referer": "https://dharmamitra.org/"
        }

# %%
trans_req = requests.post(trans_base_url,json=_create_payload(sanskrit_passage),headers=_create_headers(),stream =True)
print(trans_req.text)
# Out:
# data: {"type":"start","messageId":"4YoK3YPmnDG9NrMI"}
#
# data: {"type":"start-step"}
#
# data: {"type":"text-start","id":"txt-0"}
#
# data: {"type":"text-delta","id":"txt-0","delta":"There is"}
#
# data: {"type":"text-delta","id":"txt-0","delta":" a certain village.\n\nIn the village, there lives a miser.\n\nHe"}
#
# data: {"type":"text-delta","id":"txt-0","delta":" never gives anything to anyone at any time.\n\nOne day, that miser goes to another village.\n\nOn the way, there is a"}
#
# data: {"type":"text-delta","id":"txt-0","delta":" river.\n\nThere is a boat there.\n\nA boatman is also there.\n\nThe miser sits down in the"}
#
# data: {"type":"text-delta","id":"txt-0","delta":" boat.\n\nThe miser travels by boat along with the boatman.\n\nWhen the boat goes a little distance, then"}
#
# data: {"type":"text-delta","id":"txt-0","delta":" the wrath of nature occurs.\n\nThe wind blows with great speed.\n\nThe boat tosses about.\n\nThe miser becomes"}
#
# data: {"type":"text-delta","id":"txt-0","delta":" frightened.\n\nHe falls into the river.\n\nBut he does not know how to swim.\n\nHe cries out loudly"}
#
# data: {"type":"text-delta","id":"txt-0","delta":", \"Save me, save me!\"\n\n, \" , \".\n\nThe boatman says, \"O friend, give me"}
#
# data: {"type":"text-delta","id":"txt-0","delta":" your hand quickly!\"\n\n\" \".\n\nHowever, this man is a great miser.\n\nHe never gives anything.\n\nHe does not even"}
#
# data: {"type":"text-delta","id":"txt-0","delta":" give his own hand.\n\nThe boatman thinks, \"This man is a fool.\"\n\nHe performs a certain trick.\n\nHe says,"}
#
# data: {"type":"text-delta","id":"txt-0","delta":" \"O friend, take my hand!\"\n\n, .\n\n, \" \".\n\nThe miser at once seizes the boatman's"}
#
# data: {"type":"text-delta","id":"txt-0","delta":" hand with both of his hands.\n\nHe comes back inside the boat."}
#
# data: {"type":"text-end","id":"txt-0"}
#
# data: {"type":"finish-step"}
#
# data: {"type":"finish","finishReason":"stop"}
#
# data: {"type":"data-mitraCitation","id":"citation-meta","data":{"responseId":"ngzajpLTYbSk"}}
#
# data: [DONE]

# %%
 def _extract_data(response):
        full_text = ""

        for line in response.iter_lines():
            if not line:
                continue

            line = line.decode("utf-8")

            if line.startswith("data: "):
                event_data = line[6:]

                if event_data == "[DONE]":
                    break

                try:
                    obj = json.loads(event_data)
                except json.JSONDecodeError:
                    continue

                if obj.get("type") == "text-delta":
                    full_text += obj.get("delta", "")

        return full_text

# %%
translated_raw_data = _extract_data(trans_req)

translated_english_passage = " ".join(translated_raw_data.split())

print(translated_english_passage)
# Out:
# There is a certain village. In the village, there lives a miser. He never gives anything to anyone at any time. One day, that miser goes to another village. On the way, there is a river. There is a boat there. A boatman is also there. The miser sits down in the boat. The miser travels by boat along with the boatman. When the boat goes a little distance, then the wrath of nature occurs. The wind blows with great speed. The boat tosses about. The miser becomes frightened. He falls into the river. But he does not know how to swim. He cries out loudly, "Save me, save me!" , " , ". The boatman says, "O friend, give me your hand quickly!" " ". However, this man is a great miser. He never gives anything. He does not even give his own hand. The boatman thinks, "This man is a fool." He performs a certain trick. He says, "O friend, take my hand!" , . , " ". The miser at once seizes the boatman's hand with both of his hands. He comes back inside the boat.

# %%
import unicodedata

def normalize_diacritics(text):
    return "".join(
        c for c in unicodedata.normalize("NFD", text)
        if unicodedata.category(c) != "Mn"
    )

# %%
english_passage = normalize_diacritics(translated_english_passage)

print(english_passage)
# Out:
# There is a certain village. In the village, there lives a miser. He never gives anything to anyone at any time. One day, that miser goes to another village. On the way, there is a river. There is a boat there. A boatman is also there. The miser sits down in the boat. The miser travels by boat along with the boatman. When the boat goes a little distance, then the wrath of nature occurs. The wind blows with great speed. The boat tosses about. The miser becomes frightened. He falls into the river. But he does not know how to swim. He cries out loudly, "Save me, save me!" , " , ". The boatman says, "O friend, give me your hand quickly!" " ". However, this man is a great miser. He never gives anything. He does not even give his own hand. The boatman thinks, "This man is a fool." He performs a certain trick. He says, "O friend, take my hand!" , . , " ". The miser at once seizes the boatman's hand with both of his hands. He comes back inside the boat.

# %%
import re

def clean_translation(text):
    # Normalize whitespace
    text = re.sub(r'\s+', ' ', text).strip()

    # Remove empty quoted fragments
    text = re.sub(r'["“”\']\s*["“”\']', '', text)

    # Remove quotes containing only punctuation
    text = re.sub(r'["“”\']\s*[,.;:!?।]+\s*["“”\']', '', text)

    # Remove duplicated punctuation
    text = re.sub(r'([,.!?])\s*\1+', r'\1', text)

    # Fix punctuation spacing
    text = re.sub(r'\s+([,.!?])', r'\1', text)

    # Remove orphan punctuation
    text = re.sub(r'\s+[,.;:]+\s*(?=[A-Za-z])', ' ', text)

    # Clean quotation spacing
    text = re.sub(r'\s+([\'"])', r'\1', text)
    text = re.sub(r'([\'"])\s+', r'\1 ', text)

    return text.strip()

# %%
cleaned_english_passage = clean_translation(english_passage)
print(cleaned_english_passage)
# Out:
# There is a certain village. In the village, there lives a miser. He never gives anything to anyone at any time. One day, that miser goes to another village. On the way, there is a river. There is a boat there. A boatman is also there. The miser sits down in the boat. The miser travels by boat along with the boatman. When the boat goes a little distance, then the wrath of nature occurs. The wind blows with great speed. The boat tosses about. The miser becomes frightened. He falls into the river. But he does not know how to swim. He cries out loudly,"Save me, save me!,". The boatman says,"O friend, give me your hand quickly!". However, this man is a great miser. He never gives anything. He does not even give his own hand. The boatman thinks,"This man is a fool." He performs a certain trick. He says,"O friend, take my hand!",.,. The miser at once seizes the boatman's hand with both of his hands. He comes back inside the boat.
